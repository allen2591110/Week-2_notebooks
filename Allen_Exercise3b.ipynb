# %%
install.packages("devtools")devtools::install_github("sfsheath/cawd")install.packages("sp")
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:29: unexpected symbol
# 1: install.packages("devtools")devtools
#                                 ^
# Traceback:

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
install.packages("devtools") devtools::install_github("sfsheath/cawd") install.packages("sp")
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:30: unexpected symbol
# 1: install.packages("devtools") devtools
#                                  ^
# Traceback:

# %%
install.packages("devtools")
devtools::install_github("sfsheath/cawd")
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# ...
# from URL https://api.github.com/repos/sfsheath/cawd/zipball/master
# Installing cawd
# '/usr/lib/R/bin/R' --no-site-file --no-environ --no-save --no-restore --quiet  \
#   CMD INSTALL '/tmp/Rtmpyv34Z6/devtools2d7b56b19a/sfsheath-cawd-928f175'  \
#   --library='/srv/rlibs' --install-tests
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %%
data()

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(darmc.roman.roads.major.sp)
# Out:
# plot without title

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(	nomisma.roman.mints.sp)
# Out:
# plot without title

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.senatorial.sp)
# Out:
# plot without title

# %% [markdown]
# What I have noticed is that images seem to start with a base map and then they all appear to be layers. There does not seem to be much variation in the map outlook, just what layer you are seeing. In this case several of the images I pulled up seem to be just layers of information, possibly independent data sets that can be overlaped. I wish it could compress some of the images, because I would like to see the information about the mints and compare it to a roman empire map 200, but on the same file. Otherwise, this is a very interesting tool and it is nice to be able to pull up data sets and maps.
